# %%
# importing libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# importing datasets
dataset_train = pd.read_csv('train.csv')
dataset_test = pd.read_csv('test.csv')

# %%
dataset_train
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
dataset_test
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
# Dropping unnecessary columns from training datatest
dataset_train.drop(dataset_train.columns[[0,1,5,7,9,10,11,12]], axis = 1, inplace = True)

# %%
dataset_train
# Out:
#     Married Dependents     Education  ApplicantIncome  LoanAmount
# 0        No          0      Graduate             5849         NaN
# 1       Yes          1      Graduate             4583       128.0
# 2       Yes          0      Graduate             3000        66.0
# 3       Yes          0  Not Graduate             2583       120.0
# 4        No          0      Graduate             6000       141.0
# ..      ...        ...           ...              ...         ...
# 609      No          0      Graduate             2900        71.0
# 610     Yes         3+      Graduate             4106        40.0
# 611     Yes          1      Graduate             8072       253.0
# 612     Yes          2      Graduate             7583       187.0
# 613      No          0      Graduate             4583       133.0
#
# [614 rows x 5 columns]

# %%
# Dropping columns with no values from training dataset
df_train = dataset_train.dropna()

# %%
df_train
# Out:
#     Married Dependents     Education  ApplicantIncome  LoanAmount
# 1       Yes          1      Graduate             4583       128.0
# 2       Yes          0      Graduate             3000        66.0
# 3       Yes          0  Not Graduate             2583       120.0
# 4        No          0      Graduate             6000       141.0
# 5       Yes          2      Graduate             5417       267.0
# ..      ...        ...           ...              ...         ...
# 609      No          0      Graduate             2900        71.0
# 610     Yes         3+      Graduate             4106        40.0
# 611     Yes          1      Graduate             8072       253.0
# 612     Yes          2      Graduate             7583       187.0
# 613      No          0      Graduate             4583       133.0
#
# [579 rows x 5 columns]

# %%
# Replace with Yes with 1, No with 0 in Married column of training dataset
df_train = df_train.replace({'Married': {'Yes': 1, 'No': 0}})

# %%
df_train
# Out:
#      Married Dependents     Education  ApplicantIncome  LoanAmount
# 1          1          1      Graduate             4583       128.0
# 2          1          0      Graduate             3000        66.0
# 3          1          0  Not Graduate             2583       120.0
# 4          0          0      Graduate             6000       141.0
# 5          1          2      Graduate             5417       267.0
# ..       ...        ...           ...              ...         ...
# 609        0          0      Graduate             2900        71.0
# 610        1         3+      Graduate             4106        40.0
# 611        1          1      Graduate             8072       253.0
# 612        1          2      Graduate             7583       187.0
# 613        0          0      Graduate             4583       133.0
#
# [579 rows x 5 columns]

# %%
# Replace Graduate with 1, Not Graduate with 0 in Education column in training dataset
df_train = df_train.replace({'Education': {'Graduate': 1, 'Not Graduate': 0}})

# %%
# Replace 3+ with 4 in Dependents column of training dataset for making removing calculation problems
df_train = df_train.replace({'Dependents': {'3+': 4}})

# %%
df_train
# Out:
#      Married Dependents  Education  ApplicantIncome  LoanAmount
# 1          1          1          1             4583       128.0
# 2          1          0          1             3000        66.0
# 3          1          0          0             2583       120.0
# 4          0          0          1             6000       141.0
# 5          1          2          1             5417       267.0
# ..       ...        ...        ...              ...         ...
# 609        0          0          1             2900        71.0
# 610        1          4          1             4106        40.0
# 611        1          1          1             8072       253.0
# 612        1          2          1             7583       187.0
# 613        0          0          1             4583       133.0
#
# [579 rows x 5 columns]

# %%
# Dropping unnecessary column from test dataset
dataset_test.drop(dataset_test.columns[[0,1,5,7,9,10,11]], axis = 1, inplace = True)

# %%
dataset_test
# Out:
#     Married Dependents     Education  ApplicantIncome  LoanAmount
# 0       Yes          0      Graduate             5720       110.0
# 1       Yes          1      Graduate             3076       126.0
# 2       Yes          2      Graduate             5000       208.0
# 3       Yes          2      Graduate             2340       100.0
# 4        No          0  Not Graduate             3276        78.0
# ..      ...        ...           ...              ...         ...
# 362     Yes         3+  Not Graduate             4009       113.0
# 363     Yes          0      Graduate             4158       115.0
# 364      No          0      Graduate             3250       126.0
# 365     Yes          0      Graduate             5000       158.0
# 366      No          0      Graduate             9200        98.0
#
# [367 rows x 5 columns]

# %%
# Dropping rows with no values from test dataset
df_test = dataset_test.dropna()

# %%
df_test
# Out:
#     Married Dependents     Education  ApplicantIncome  LoanAmount
# 0       Yes          0      Graduate             5720       110.0
# 1       Yes          1      Graduate             3076       126.0
# 2       Yes          2      Graduate             5000       208.0
# 3       Yes          2      Graduate             2340       100.0
# 4        No          0  Not Graduate             3276        78.0
# ..      ...        ...           ...              ...         ...
# 362     Yes         3+  Not Graduate             4009       113.0
# 363     Yes          0      Graduate             4158       115.0
# 364      No          0      Graduate             3250       126.0
# 365     Yes          0      Graduate             5000       158.0
# 366      No          0      Graduate             9200        98.0
#
# [353 rows x 5 columns]

# %%
# Replace Yes with 1, No with 0 in Married column of test dataset
df_test = df_test.replace({'Married': {'Yes': 1, 'No': 0}})

# %%
df_test
# Out:
#      Married Dependents     Education  ApplicantIncome  LoanAmount
# 0          1          0      Graduate             5720       110.0
# 1          1          1      Graduate             3076       126.0
# 2          1          2      Graduate             5000       208.0
# 3          1          2      Graduate             2340       100.0
# 4          0          0  Not Graduate             3276        78.0
# ..       ...        ...           ...              ...         ...
# 362        1         3+  Not Graduate             4009       113.0
# 363        1          0      Graduate             4158       115.0
# 364        0          0      Graduate             3250       126.0
# 365        1          0      Graduate             5000       158.0
# 366        0          0      Graduate             9200        98.0
#
# [353 rows x 5 columns]

# %%
# Replace Graduate with 1, Not Graduate 0 in Education dataset of test dataset
df_test = df_test.replace({'Education': {'Graduate': 1, 'Not Graduate': 0}})

# %%
# Replace 3+ with 4 in Dependents column of test dataset for removing problem in calculations
df_test = df_test.replace({'Dependents': {'3+': 4}})

# %%
df_test
# Out:
#      Married Dependents  Education  ApplicantIncome  LoanAmount
# 0          1          0          1             5720       110.0
# 1          1          1          1             3076       126.0
# 2          1          2          1             5000       208.0
# 3          1          2          1             2340       100.0
# 4          0          0          0             3276        78.0
# ..       ...        ...        ...              ...         ...
# 362        1          4          0             4009       113.0
# 363        1          0          1             4158       115.0
# 364        0          0          1             3250       126.0
# 365        1          0          1             5000       158.0
# 366        0          0          1             9200        98.0
#
# [353 rows x 5 columns]

# %%
x_train = df_train.iloc[:, :-1].values
y_train = df_train.iloc[:, -1].values

# %%
x_test = df_test.iloc[:, :-1].values
y_test = df_test.iloc[:, -1].values

# %%
# Training the model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# making prediction after training the model
y_pred = regressor.predict(x_test)
np.set_printoptions(precision = 2)

# %%
len(y_test)
# Out:
# 353

# %%
len(y_pred)
# Out:
# 353

# %%
y_test
# Out:
# array([110., 126., 208., 100.,  78., 152.,  59., 147., 280., 123.,  90.,
#        162.,  40., 166., 124., 131., 200., 126., 300., 100.,  48.,  28.,
#        101., 125., 290., 148., 140., 275.,  57., 125.,  75., 192., 152.,
#        158., 101., 176., 185.,  90., 116., 138., 100., 110.,  90., 200.,
#         84., 185., 108., 187., 187., 124., 120., 160.,  30.,  92., 130.,
#        130., 134., 176.,  90., 110., 125., 189., 108., 125., 138., 135.,
#        130., 187., 188.,  65., 139., 232., 144., 155., 186.,  50., 185.,
#        163., 360., 149., 257., 131., 102., 135.,  95.,  77., 200., 130.,
#        390., 185., 100., 123., 110., 256., 140.,  61., 188., 131., 116.,
#         50., 107., 200., 119., 120., 140., 165., 108., 102., 122., 160.,
#        157., 180.,  80., 104., 213.,  65., 146., 135., 187., 300., 120.,
#         71., 225.,  70.,  70., 124., 132., 105.,  90.,  83., 125., 147.,
#        120., 103., 150., 100., 139., 550., 260., 150.,  90., 199., 139.,
# ...

# %%
y_pred
# Out:
# array([155.84, 140.75, 160.01, 140.01,  97.55, 107.09,  94.45, 129.58,
#        224.95,  90.96,  96.16, 134.05, 145.44, 213.97, 130.03, 142.35,
#        156.88, 160.47, 182.22, 104.71, 109.8 , 107.75, 124.33, 101.23,
#        153.44,  94.93, 155.22, 169.23, 141.19, 117.06,  91.55, 169.42,
#        119.51, 133.75, 133.43, 118.62, 177.69, 129.87, 138.8 , 122.33,
#        155.16, 122.34, 103.97, 143.82, 122.5 , 144.86,  90.63, 146.02,
#        170.15, 135.81, 136.3 , 143.94, 153.37, 130.62, 115.61, 106.02,
#        149.58, 143.31, 167.49, 108.97, 165.59, 141.88, 110.73, 143.75,
#        134.76, 126.16, 138.73, 170.48, 131.31, 128.5 , 148.32, 142.15,
#        126.53, 121.88, 136.81, 142.74, 172.62, 160.79, 677.55, 131.5 ,
#        176.37, 146.34, 157.27, 139.68, 117.99, 106.83, 132.97, 136.8 ,
#        233.67, 150.44, 136.24, 152.28, 179.08, 142.68, 139.15, 205.1 ,
#        183.4 , 128.42, 146.96, 120.6 , 111.8 , 138.52, 106.93, 165.94,
# ...

# %%
numrows = len(y_test)

# %%
# Creating new dataframe which only contains the actual loan amount and the predicted loan amount
regression_df = pd.DataFrame({'Original_Loan_Amount':[0.0]*numrows,
                              'Predicted_Loan_Amount':[0.0]*numrows})

# %%
seq = ['Original_Loan_Amount',
       'Predicted_Loan_Amount']

# %%
regression_df = regression_df.reindex(columns=seq)

# %%
for i in range(0 , numrows):
    real_values = y_test[i]
    predicted_values = y_pred[i]
    
    regression_df.iat[i,0] = real_values
    regression_df.iat[i,1] = predicted_values


regression_df = regression_df.dropna() #exclude any rows with missing data
print(regression_df)
# Out:
#      Original_Loan_Amount  Predicted_Loan_Amount
# 0                   110.0             155.844490
# 1                   126.0             140.749429
# 2                   208.0             160.014686
# 3                   100.0             140.006270
# 4                    78.0              97.553295
# ..                    ...                    ...
# 348                 113.0             140.129786
# 349                 115.0             144.095186
# 350                 126.0             119.374370
# 351                 158.0             150.428678
# 352                  98.0             164.130039
#
# [353 rows x 2 columns]

# %%
# print the actual and predicted loan amount in a new csv file
regression_df.to_csv('predict_loan.csv', index = True)
