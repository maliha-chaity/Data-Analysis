# %%
# importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# importing dataset, assigning independent variable x and dependent variable y
dataset = pd.read_csv('iris_dataset.csv')
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# splitting dataset into training set and test set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state = 0)

# %%
x_train
# Out:
# array([[6.4, 3.1, 5.5, 1.8],
#        [5.4, 3. , 4.5, 1.5],
#        [5.2, 3.5, 1.5, 0.2],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.2],
#        [5.2, 2.7, 3.9, 1.4],
#        [5.7, 3.8, 1.7, 0.3],
#        [6. , 2.7, 5.1, 1.6],
#        [5.9, 3. , 4.2, 1.5],
#        [5.8, 2.6, 4. , 1.2],
#        [6.8, 3. , 5.5, 2.1],
#        [4.7, 3.2, 1.3, 0.2],
#        [6.9, 3.1, 5.1, 2.3],
#        [5. , 3.5, 1.6, 0.6],
#        [5.4, 3.7, 1.5, 0.2],
#        [5. , 2. , 3.5, 1. ],
#        [6.5, 3. , 5.5, 1.8],
#        [6.7, 3.3, 5.7, 2.5],
#        [6. , 2.2, 5. , 1.5],
#        [6.7, 2.5, 5.8, 1.8],
#        [5.6, 2.5, 3.9, 1.1],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [5.5, 2.4, 3.8, 1.1],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.3, 2.8, 5.1, 1.5],
#        [4.9, 2.5, 4.5, 1.7],
#        [6.3, 2.5, 5. , 1.9],
#        [7. , 3.2, 4.7, 1.4],
#        [6.5, 3. , 5.2, 2. ],
#        [6. , 3.4, 4.5, 1.6],
#        [4.8, 3.1, 1.6, 0.2],
# ...

# %%
y_train
# Out:
# array(['virginica', 'versicolor', 'setosa', 'virginica', 'virginica',
#        'versicolor', 'setosa', 'versicolor', 'versicolor', 'versicolor',
#        'virginica', 'setosa', 'virginica', 'setosa', 'setosa',
#        'versicolor', 'virginica', 'virginica', 'virginica', 'virginica',
#        'versicolor', 'virginica', 'versicolor', 'versicolor', 'virginica',
#        'virginica', 'virginica', 'virginica', 'versicolor', 'virginica',
#        'versicolor', 'setosa', 'virginica', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'virginica', 'setosa', 'setosa',
#        'virginica', 'versicolor', 'setosa', 'setosa', 'versicolor',
#        'setosa', 'virginica', 'versicolor', 'setosa', 'versicolor',
#        'virginica', 'versicolor', 'setosa', 'virginica', 'virginica',
#        'virginica', 'virginica', 'setosa', 'setosa', 'virginica',
#        'virginica', 'setosa', 'virginica', 'setosa', 'virginica',
# ...

# %%
x_test
# Out:
# array([[5.8, 2.8, 5.1, 2.4],
#        [6. , 2.2, 4. , 1. ],
#        [5.5, 4.2, 1.4, 0.2],
#        [7.3, 2.9, 6.3, 1.8],
#        [5. , 3.4, 1.5, 0.2],
#        [6.3, 3.3, 6. , 2.5],
#        [5. , 3.5, 1.3, 0.3],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.1, 2.8, 4. , 1.3],
#        [6.1, 2.6, 5.6, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.5, 2.8, 4.6, 1.5],
#        [6.1, 2.9, 4.7, 1.4],
#        [4.9, 3.1, 1.5, 0.1],
#        [6. , 2.9, 4.5, 1.5],
#        [5.5, 2.6, 4.4, 1.2],
#        [4.8, 3. , 1.4, 0.3],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.6, 2.8, 4.9, 2. ],
#        [5.6, 3. , 4.5, 1.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [6.2, 2.8, 4.8, 1.8],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.8, 1.9, 0.4],
#        [6.2, 2.9, 4.3, 1.3],
#        [5. , 2.3, 3.3, 1. ],
#        [5. , 3.4, 1.6, 0.4]])

# %%
y_test
# Out:
# array(['virginica', 'versicolor', 'setosa', 'virginica', 'setosa',
#        'virginica', 'setosa', 'versicolor', 'versicolor', 'versicolor',
#        'virginica', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'setosa', 'versicolor', 'versicolor', 'setosa',
#        'setosa', 'virginica', 'versicolor', 'setosa', 'setosa',
#        'virginica', 'setosa', 'setosa', 'versicolor', 'versicolor',
#        'setosa'], dtype=object)

# %%
# creating K-NN classifier model and training the model
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# predicting species
y_pred = classifier.predict(x_test)
np.set_printoptions(precision = 2)
print("Predicted values are:")
print(y_pred)
# Out:
# Predicted values are:
# ['virginica' 'versicolor' 'setosa' 'virginica' 'setosa' 'virginica'
#  'setosa' 'versicolor' 'versicolor' 'versicolor' 'virginica' 'versicolor'
#  'versicolor' 'versicolor' 'virginica' 'setosa' 'versicolor' 'versicolor'
#  'setosa' 'setosa' 'virginica' 'versicolor' 'setosa' 'setosa' 'virginica'
#  'setosa' 'setosa' 'versicolor' 'versicolor' 'setosa']

# %%
numrows = len(y_test)

# %%
# creating new dataframe to store Original_species and Predicted_species
regression_df = pd.DataFrame({'Original_species':[0.0]*numrows,
                              'Predicted_species':[0.0]*numrows})

# %%
seq = ['Original_species',
       'Predicted_species']

# %%
regression_df = regression_df.reindex(columns=seq)

# %%
for i in range(0 , numrows):
    real_values = y_test[i]
    predicted_values = y_pred[i]
    
    if real_values == "setosa":
        real_values = 0
    elif real_values == "versicolor":
        real_values = 1
    else:
        real_values = 2
        
    
    if predicted_values == "setosa":
        predicted_values = 0
    elif predicted_values == "versicolor":
        predicted_values = 1
    else:
        predicted_values = 2    
    
    regression_df.iloc[i,0] = real_values
    regression_df.iloc[i,1] = predicted_values


regression_df = regression_df.dropna() #exclude any rows with missing data
print(regression_df)
# Out:
#     Original_species  Predicted_species
# 0                2.0                2.0
# 1                1.0                1.0
# 2                0.0                0.0
# 3                2.0                2.0
# 4                0.0                0.0
# 5                2.0                2.0
# 6                0.0                0.0
# 7                1.0                1.0
# 8                1.0                1.0
# 9                1.0                1.0
# 10               2.0                2.0
# 11               1.0                1.0
# 12               1.0                1.0
# 13               1.0                1.0
# 14               1.0                2.0
# 15               0.0                0.0
# 16               1.0                1.0
# 17               1.0                1.0
# 18               0.0                0.0
# 19               0.0                0.0
# 20               2.0                2.0
# 21               1.0                1.0
# ...

# %%
# replacing 0 with "setosa" and storing the updated dataframe into dataframe df1
df1 = regression_df.replace(to_replace =0, value ="setosa")

# %%
df1
# Out:
#    Original_species Predicted_species
# 0                 2                 2
# 1                 1                 1
# 2            setosa            setosa
# 3                 2                 2
# 4            setosa            setosa
# 5                 2                 2
# 6            setosa            setosa
# 7                 1                 1
# 8                 1                 1
# 9                 1                 1
# 10                2                 2
# 11                1                 1
# 12                1                 1
# 13                1                 1
# 14                1                 2
# 15           setosa            setosa
# 16                1                 1
# 17                1                 1
# 18           setosa            setosa
# 19           setosa            setosa
# 20                2                 2
# 21                1                 1
# 22           setosa            setosa
# 23           setosa            setosa
# ...

# %%
# replacing 1 with "versicolor" and storing the updated dataframe into dataframe df2
df2 = df1.replace(to_replace =1, value ="versicolor")

# %%
df2
# Out:
#    Original_species Predicted_species
# 0                 2                 2
# 1        versicolor        versicolor
# 2            setosa            setosa
# 3                 2                 2
# 4            setosa            setosa
# 5                 2                 2
# 6            setosa            setosa
# 7        versicolor        versicolor
# 8        versicolor        versicolor
# 9        versicolor        versicolor
# 10                2                 2
# 11       versicolor        versicolor
# 12       versicolor        versicolor
# 13       versicolor        versicolor
# 14       versicolor                 2
# 15           setosa            setosa
# 16       versicolor        versicolor
# 17       versicolor        versicolor
# 18           setosa            setosa
# 19           setosa            setosa
# 20                2                 2
# 21       versicolor        versicolor
# 22           setosa            setosa
# 23           setosa            setosa
# ...

# %%
# replacing 2 with "virginica" and storing the updated dataframe into dataframe df3
df3 = df2.replace(to_replace =2, value ="virginica")

# %%
df3
# Out:
#    Original_species Predicted_species
# 0         virginica         virginica
# 1        versicolor        versicolor
# 2            setosa            setosa
# 3         virginica         virginica
# 4            setosa            setosa
# 5         virginica         virginica
# 6            setosa            setosa
# 7        versicolor        versicolor
# 8        versicolor        versicolor
# 9        versicolor        versicolor
# 10        virginica         virginica
# 11       versicolor        versicolor
# 12       versicolor        versicolor
# 13       versicolor        versicolor
# 14       versicolor         virginica
# 15           setosa            setosa
# 16       versicolor        versicolor
# 17       versicolor        versicolor
# 18           setosa            setosa
# 19           setosa            setosa
# 20        virginica         virginica
# 21       versicolor        versicolor
# 22           setosa            setosa
# 23           setosa            setosa
# ...

# %%
# printing Original_species and Predicted_species in a new csv file
df3.to_csv('predict_species.csv', index = True)

# %%
# making a confusion matrix
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[11,  0,  0],
#        [ 0, 12,  1],
#        [ 0,  0,  6]], dtype=int64)

# %%
# calculating accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.9666666666666667
